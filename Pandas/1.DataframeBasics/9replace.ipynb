# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('weather_new.csv',parse_dates=['day'])
df.set_index('day',inplace=True)
df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-04        -9999          9  Sunny
# 2017-01-05           28      -9999   Snow
# 2017-01-06        -9999          7    NaN
# 2017-01-07           32      -9999   Rain
# 2017-01-08           40          6  Sunny

# %%
df.dropna(how='all',inplace=True)
df
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01           32          6   Rain
# 2017-01-04        -9999          9  Sunny
# 2017-01-05           28      -9999   Snow
# 2017-01-06        -9999          7    NaN
# 2017-01-07           32      -9999   Rain
# 2017-01-08           40          6  Sunny

# %%
dfnew=df.replace(-9999,np.NaN)
dfnew
# Out:
#             temperature  windspeed  event
# day
# 2017-01-01         32.0        6.0   Rain
# 2017-01-04          NaN        9.0  Sunny
# 2017-01-05         28.0        NaN   Snow
# 2017-01-06          NaN        7.0    NaN
# 2017-01-07         32.0        NaN   Rain
# 2017-01-08         40.0        6.0  Sunny

# %%
dt=pd.date_range('01-01-2017','01-08-2017')
idx=pd.DatetimeIndex(dt)
dfnew=dfnew.reindex(idx)
dfnew
# Out:
#             temperature  windspeed  event
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02          NaN        NaN    NaN
# 2017-01-03          NaN        NaN    NaN
# 2017-01-04          NaN        9.0  Sunny
# 2017-01-05         28.0        NaN   Snow
# 2017-01-06          NaN        7.0    NaN
# 2017-01-07         32.0        NaN   Rain
# 2017-01-08         40.0        6.0  Sunny

# %%
dfnew.interpolate()
# Out:
#             temperature  windspeed  event
# 2017-01-01         32.0        6.0   Rain
# 2017-01-02         31.0        7.0    NaN
# 2017-01-03         30.0        8.0    NaN
# 2017-01-04         29.0        9.0  Sunny
# 2017-01-05         28.0        8.0   Snow
# 2017-01-06         30.0        7.0    NaN
# 2017-01-07         32.0        6.5   Rain
# 2017-01-08         40.0        6.0  Sunny

# %%
df

# %%
newdf=df.replace({
  -9999:np.NaN,
  np.NaN:'no event'
})
newdf
# Out:
#             temperature  windspeed     event
# day
# 2017-01-01         32.0        6.0      Rain
# 2017-01-04          NaN        9.0     Sunny
# 2017-01-05         28.0        NaN      Snow
# 2017-01-06          NaN        7.0  no event
# 2017-01-07         32.0        NaN      Rain
# 2017-01-08         40.0        6.0     Sunny

# %%
#|---------------------------------------------------------------------------|#
#| TO REMOVE LETTERS FROM COLUMNS
#|---------------------------------------------------------------------------|#

dfnew=df.replace({
  'temperature':'[A-Za-z]',
  'windspeed':'[A-Za-z]'
  },'',regex=True)
